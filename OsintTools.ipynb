# %% [markdown]
# ## Herramientas OSINT.
#
# Este script contiene diferentes herramientas que se utilizan en OSINT para recopilar información de distintos objetivos (páginas web, usuarios en redes sociales, teléfonos, entre otras)

# %% [markdown]
# ### Netcraft
# Netcraft (https://www.netcraft.com/) es una potente herramienta web de OSINT (Inteligencia de Fuentes Abiertas) que se utiliza para el reconocimiento pasivo y ofrece información detallada sobre la infraestructura de un sitio web, su historial de alojamiento, su dirección IP y su pila tecnológica. Es ampliamente utilizada por profesionales de seguridad para la detección de errores, la identificación de posibles superficies de ataque y el seguimiento de certificados SSL.
#
# ### API Netcraft de Cybersight Security
#
# El cliente de la API Netcraft de Cybersight Security (https://github.com/Cybersight-Security/Netcraft-API-Client) es una interfaz de línea de comandos de Python que permite a los profesionales de seguridad interactuar con la API de Netcraft para informar y gestionar amenazas de ciberseguridad. Esta herramienta simplifica el proceso de envío de URL maliciosas, correos electrónicos y sitios web bloqueados incorrectamente a la plataforma de inteligencia de amenazas de Netcraft.

# %%
# !git clone https://github.com/Cybersight-Security/Netcraft-API-Client.git
# !pip install -r Netcraft-API-Client/requirements.txt
# Out:
# Cloning into 'Netcraft-API-Client'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 83 (delta 28), reused 32 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (83/83), 144.99 KiB | 2.68 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# ...

# %% [markdown]
# ### Instrucciones
#
# microsoft.com

# %%
# !python Netcraft-API-Client/main.py
# Out:
# Netcraft API Commands:
# 1. Report a single URL
# 2. Report URLs from a file
# 3. Report a malicious mail
# 4. Report an incorrectly blocked URL
# 5. Get submission details
# 6. Get submission files
# 7. Get submission URLs
# 8. Report an issue with a submission
# 9. Get available tags
# 10. Unsubscribe from notifications
# 0. Exit
# Enter your choice:

# %% [markdown]
# ###PyWhat
#
# PyWhat (https://github.com/bee-san/pyWhat) es una herramienta capaz de identificar cualquier cosa. La función de what es identificar qué es algo. Ya sea un archivo o texto, o incluso el hexadecimal de un archivo.

# %%
# !pip install pywhat

# %%
# !what 0x52908400098527886E0F7030069857D2E4169EE7
# !what "dQw4w9WgXcQ"

# %% [markdown]
# ### PyWhatKit
#
# PyWhatKit (https://github.com/Ankit404butfound/PyWhatKit) es una librería de Python con diversas funciones útiles. Es fácil de usar y no requiere configuración adicional. Actualmente, es una de las librerías más populares para la automatización de WhatsApp y YouTube. Publicamos actualizaciones frecuentes con nuevas funciones y correcciones de errores.

# %%
# !python3 -m pip install pywhatkit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.2/171.2 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyautogui: filename=pyautogui-0.9.54-py3-none-any.whl size=37685 sha256=60a00d2128986e901073abf8c8390bcf159842113a8e448a067bcee72cab6632
# ...

# %%
import os
os.environ['DISPLAY'] = 'localhost:0'
import pywhatkit

# Send a WhatsApp Message to a Contact at 1:30 PM
pywhatkit.sendwhatmsg("+910123456789", "Hi", 13, 30)

# Send an Image to a Group with the Caption as Hello
pywhatkit.sendwhats_image("AB123CDEFGHijklmn", "Images/Hello.png", "Hello")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/Xlib/support/unix_connect.py in get_socket(dname, host, dno)
#      70             s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# ---> 71             s.connect((host, 6000 + dno))
#      72
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# DisplayConnectionError                    Traceback (most recent call last)
# /tmp/ipython-input-16166/504161635.py in <cell line: 0>()
#       1 import os
#       2 os.environ['DISPLAY'] = 'localhost:0'
# ----> 3 import pywhatkit
#       4
#       5 # Send a WhatsApp Message to a Contact at 1:30 PM
#
# /usr/local/lib/python3.12/dist-packages/pywhatkit/__init__.py in <module>
# ...

# %% [markdown]
# ### Nmap
#
# Nmap ("Network Mapper") (https://nmap.org/) es una utilidad gratuita y de código abierto para el descubrimiento de redes y la auditoría de seguridad. Muchos administradores de sistemas y redes también la encuentran útil para tareas como el inventario de red, la gestión de programas de actualización de servicios y la monitorización del tiempo de actividad de hosts o servicios.
#
# ### python-nmap
#
# Python-nmap (https://pypi.org/project/python-nmap/) es una biblioteca de Python que facilita el uso del escáner de puertos nmap. Permite manipular fácilmente los resultados del escaneo nmap y es una herramienta ideal para administradores de sistemas que desean automatizar las tareas de escaneo y los informes.

# %%
# !pip install python-nmap
# !apt install nmap
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   liblinear4 liblua5.3-0 libpcap0.8 lua-lpeg nmap-common
# Suggested packages:
#   liblinear-tools liblinear-dev ncat ndiff zenmap
# The following NEW packages will be installed:
#   liblinear4 liblua5.3-0 libpcap0.8 lua-lpeg nmap nmap-common
# 0 upgraded, 6 newly installed, 0 to remove and 2 not upgraded.
# Need to get 6,029 kB of archives.
# After this operation, 26.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpcap0.8 amd64 1.10.1-4ubuntu1.22.04.1 [145 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblinear4 amd64 2.3.0+dfsg-5 [41.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblua5.3-0 amd64 5.3.6-1build1 [140 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lua-lpeg amd64 1.0.2-1 [31.4 kB]
# ...

# %%
import nmap

scanner = nmap.PortScanner()

# Define target IP address or hostname
target = "scanme.nmap.org"

# Run a basic scan on the target
scanner.scan(target)

# Print the scan results
for host in scanner.all_hosts():
    print("Host: ", host)
    print("State: ", scanner[host].state())
    for proto in scanner[host].all_protocols():
        print("Protocol: ", proto)
        ports = scanner[host][proto].keys()
        for port in ports:
            print("Port: ", port, "State: ", scanner[host][proto][port]['state'])
# Out:
# Host:  45.33.32.156
# State:  up
# Protocol:  tcp
# Port:  22 State:  open
# Port:  80 State:  open
# Port:  9929 State:  open
# Port:  31337 State:  open

# %% [markdown]
# ### Sherlock
#
# Sherlock (https://github.com/sherlock-project/sherlock) es una herramienta que facilita la búsqueda de cuentas de redes sociales por nombre de usuario en más de 400 redes sociales

# %%
# !pip install sherlock-project
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 26.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stem: filename=stem-1.8.2-py3-none-any.whl size=436205 sha256=71cf451839b9c8084346c4fb123cc9133348b3940f628ac6a5f27b0c91ce3632
#   Stored in directory: /root/.cache/pip/wheels/91/3d/a8/3f5ed3c98e159d39092654ba746168d5bc58c1eb0d96702f8f
# Successfully built stem
# ...

# %% [markdown]
# Instrucciones:
#
# Vamos a buscar al user123 en las redes sociales.

# %%
# !sherlock user123
# Out:
# [*] Checking username user123 on:
#
# [+] 7Cups: https://www.7cups.com/@user123
# [+] About.me: https://about.me/user123
# [+] AllMyLinks: https://allmylinks.com/user123
# [+] AniWorld: https://aniworld.to/user/profil/user123
# [+] Anilist: https://anilist.co/user/user123/
# [+] Apple Developer: https://developer.apple.com/forums/profile/user123
# [+] Apple Discussions: https://discussions.apple.com/profile/user123
# [+] Atcoder: https://atcoder.jp/users/user123
# [+] Vjudge: https://VJudge.net/user/user123
# [+] Audiojungle: https://audiojungle.net/user/user123
# [+] Bezuzyteczna: https://bezuzyteczna.pl/uzytkownicy/user123
# [+] Bluesky: https://bsky.app/profile/user123.bsky.social
# [+] BoardGameGeek: https://boardgamegeek.com/user/user123
# [+] BraveCommunity: https://community.brave.com/u/user123/
# [+] BugCrowd: https://bugcrowd.com/user123
# [+] BuyMeACoffee: https://buymeacoff.ee/user123
# [+] BuzzFeed: https://buzzfeed.com/user123
# ...

# %% [markdown]
# ###PhoneInfoga
#
# PhoneInfoga (https://github.com/la-deep-web/Phoneinfoga) es una de las herramientas más avanzadas para escanear números de teléfono internacionales. Permite recopilar información básica como país, área, operador y tipo de línea, y luego utilizar diversas técnicas para intentar encontrar el proveedor de VoIP o identificar al propietario. Funciona con un conjunto de escáneres que deben configurarse para que la herramienta sea eficaz. PhoneInfoga no lo automatiza todo, simplemente facilita la investigación de números de teléfono.

# %%
# !git clone https://github.com/la-deep-web/Phoneinfoga.git
# !python3 -m pip install -r Phoneinfoga/requirements.txt
# !pip install urllib3==1.26.9
# Out:
# fatal: destination path 'Phoneinfoga' already exists and is not an empty directory.
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...

# %%
# !python3 Phoneinfoga/phoneinfoga.py -n +34968623167 -s ovh
# Out:
# /content/Phoneinfoga/phoneinfoga.py:20: SyntaxWarning: invalid escape sequence '\ '
#   print("   / _ \ |__   ___  _ __   ___  \_   \_ __  / _| ___   __ _  __ _ ")
# /content/Phoneinfoga/phoneinfoga.py:21: SyntaxWarning: invalid escape sequence '\ '
#   print("  / /_)/ '_ \ / _ \| '_ \ / _ \  / /\/ '_ \| |_ / _ \ / _` |/ _` |")
# /content/Phoneinfoga/phoneinfoga.py:22: SyntaxWarning: invalid escape sequence '\/'
#   print(" / ___/| | | | (_) | | | |  __/\/ /_ | | | |  _| (_) | (_| | (_| |")
# /content/Phoneinfoga/phoneinfoga.py:23: SyntaxWarning: invalid escape sequence '\/'
#   print(" \/    |_| |_|\___/|_| |_|\___\____/ |_| |_|_|  \___/ \__, |\__,_|")
# /content/Phoneinfoga/phoneinfoga.py:214: SyntaxWarning: invalid escape sequence '\+'
#   return re.sub("(?:\+)?(?:[^[0-9]*)", "", InputNumber)
#     ___ _                       _____        __
#    / _ \ |__   ___  _ __   ___  \_   \_ __  / _| ___   __ _  __ _
#   / /_)/ '_ \ / _ \| '_ \ / _ \  / /\/ '_ \| |_ / _ \ / _` |/ _` |
# ...

# %% [markdown]
# ### Sublist3r
#
# Sublist3r (https://github.com/aboul3la/Sublist3r) es una herramienta de Python diseñada para enumerar subdominios de sitios web mediante OSINT. Ayuda a los evaluadores de red y a los buscadores de errores a recopilar subdominios para el dominio objetivo. Sublist3r enumera subdominios utilizando diversos motores de búsqueda como Google, Yahoo, Bing, Baidu y Ask. También enumera subdominios utilizando Netcraft, Virustotal, ThreatCrowd, DNSdumpster y ReverseDNS.

# %%
# !git clone https://github.com/aboul3la/Sublist3r.git
# !python -m pip install -r Sublist3r/requirements.txt
# !pip install requests
# !sudo pip install dnspython
# !sudo pip install argparse
# Out:
# fatal: destination path 'Sublist3r' already exists and is not an empty directory.
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...

# %%
# !python Sublist3r/sublist3r.py -d google.com
# Out:
# /content/Sublist3r/sublist3r.py:78: SyntaxWarning: invalid escape sequence '\_'
#   \___ \| | | | '_ \| | / __| __| |_ \| '__|
# /content/Sublist3r/sublist3r.py:286: SyntaxWarning: invalid escape sequence '\/'
#   link_regx = re.compile('<cite.*?>(.*?)<\/cite>')
# /content/Sublist3r/sublist3r.py:343: SyntaxWarning: invalid escape sequence '\/'
#   link = re.sub("<(\/)?b>", "", link)
# /content/Sublist3r/sublist3r.py:439: SyntaxWarning: invalid escape sequence '\/'
#   link = re.sub('<(\/)?strong>|<span.*?>|<|>', '', link)
# /content/Sublist3r/sublist3r.py:658: SyntaxWarning: invalid escape sequence '\/'
#   tbl_regex = re.compile('<a name="hostanchor"><\/a>Host Records.*?<table.*?>(.*?)</table>', re.S)
# /content/Sublist3r/sublist3r.py:898: SyntaxWarning: invalid escape sequence '\-'
#   domain_check = re.compile("^(http|https)?[a-zA-Z0-9]+([\-\.]{1}[a-zA-Z0-9]+)*\.[a-zA-Z]{2,}$")
#
#                  ____        _     _ _     _   _____
# ...

# %% [markdown]
# ## Recon-ng
#
# Recon-ng (https://github.com/rubrod/recon-es) es un framework de reconocimiento completo, diseñado con el objetivo de proporcionar un entorno potente para realizar reconocimiento web de código abierto de forma rápida y exhaustiva.

# %%
# !git clone https://github.com/lanmaster53/recon-ng.git
# !pip3 install -r recon-ng/REQUIREMENTS
# !python3 recon-ng
# Out:
# Cloning into 'recon-ng'...
# remote: Enumerating objects: 9554, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 9554 (delta 17), reused 9 (delta 9), pack-reused 9524 (from 2)
# Receiving objects: 100% (9554/9554), 3.08 MiB | 10.05 MiB/s, done.
# Resolving deltas: 100% (4974/4974), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 36.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 3.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.4/110.4 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.1/396.1 kB 28.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Instrucciones:
#
# [recon-ng][default]> show domains
#
# [recon-ng][default] > show info
#
# [recon-ng][default] > modules load hackertarget
#
# [recon-ng][default] > modules load hackertarget
#
# [recon-ng][default][hackertarget] > options set SOURCE tesla.com
#
# [recon-ng][default][hackertarget] > info

# %%
# !python3 recon-ng/recon-ng
# Out:
#     _/_/_/    _/_/_/_/    _/_/_/    _/_/_/    _/      _/            _/      _/    _/_/_/
#    _/    _/  _/        _/        _/      _/  _/_/    _/            _/_/    _/  _/
#   _/_/_/    _/_/_/    _/        _/      _/  _/  _/  _/  _/_/_/_/  _/  _/  _/  _/  _/_/_/
#  _/    _/  _/        _/        _/      _/  _/    _/_/            _/    _/_/  _/      _/
# _/    _/  _/_/_/_/    _/_/_/    _/_/_/    _/      _/            _/      _/    _/_/_/
#
#
#                                           /\
#                                          / \\ /\
#     Sponsored by...               /\  /\/  \\V  \/\
#                                  / \\/ // \\\\\ \\ \/\
#                                 // // BLACK HILLS \/ \\
#                                www.blackhillsinfosec.com
#
#                   ____   ____   ____   ____ _____ _  ____   ____  ____
#                  |____] | ___/ |____| |       |   | |____  |____ |
#                  |      |   \_ |    | |____   |   |  ____| |____ |____
# ...

# %% [markdown]
# ### Spiderfoot
#
# Spiderfoot (https://spiderfoot.org/) es una herramienta de automatización OSINT de código abierto que le ayuda a recopilar inteligencia de una amplia gama de fuentes públicas. Gracias a su amplia gama de módulos, Spiderfoot le permite recopilar y analizar datos relacionados con dominios, direcciones IP, correos electrónicos, cuentas de redes sociales y mucho más. Se utiliza ampliamente en inteligencia de ciberamenazas, análisis forense digital y tareas de reconocimiento.

# %%
#!git clone https://github.com/smicallef/spiderfoot.git
#!pip install -r spiderfoot/requirements.txt
#!ls spiderfoot
# !python ./spiderfoot/sf.py -l 127.0.0.1:5001
# Out:
# *************************************************************
#  Use SpiderFoot by starting your web browser of choice and
#  browse to http://127.0.0.1:5001/
# *************************************************************
#
# 2026-02-26 12:04:40,538 [INFO] sf : Starting web server at 127.0.0.1:5001 ...
# 2026-02-26 12:04:40,539 [WARNING] sf :
# ********************************************************************
# ...
# Please consider adding authentication to protect this instance!
# Refer to https://www.spiderfoot.net/documentation/#security.
# ********************************************************************

# %% [markdown]
# ### Meta detective
#
# MetaDetective (https://github.com/franckferman/MetaDetective): Análisis avanzado de metadatos y web scraping.
#
# En el ámbito de la ciberseguridad, los metadatos son más que información incrustada; son una puerta de entrada a perspectivas reveladoras, que a menudo revelan pistas cruciales en OSINT y pentesting.

# %%
#!git clone https://github.com/franckferman/MetaDetective.git
# !python MetaDetective/src/MetaDetective/MetaDetective.py -d directory
# Out:
# ___  ___     _       ______     _            _   _     	 	 _==\/==_
# |  \/  |    | |      |  _  \   | |          | | (_)    		/________\
# | .  . | ___| |_ __ _| | | |___| |_ ___  ___| |_ ___   _____	/ 0 \ o b
# | |\/| |/ _ \ __/ _` | | | / _ \ __/ _ \/ __| __| \ \ / / _ \	\___/'  |
# | |  | |  __/ || (_| | |/ /  __/ ||  __/ (__| |_| |\ V /  __/	  H\__/'
# \_|  |_/\___|\__\__,_|___/ \___|\__\___|\___|\__|_| \_/ \___|	  H
#
# Error: exiftool is not installed. Please install it to continue.
